# %% [markdown]
# # Hands-On Pertemuan 11: Advanced MongoDB Operations and Data Query

# %% [markdown]
# ## Objectives:
# - Dive into advanced query operations and aggregation pipelines in MongoDB.
# - Enhance skills in filtering, grouping, and analyzing data with MongoDB.
# - Master complex MongoDB operations for real-world data scenarios.

# %% [markdown]
# ### 1. Advanced CRUD Operations
# - **Exercise 1**: Use `bulk_write` to insert, update, and delete multiple documents simultaneously.
# - **Task 1**: Insert a dataset of `courses` where each course has multiple student enrollments, then display the data.

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient, InsertOne, UpdateOne, DeleteOne

# Establish client connection
client = MongoClient('mongodb+srv://akbarindra:Akbarmagelang0@cluster0.9rnw4.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
db = client['university_db']
courses_collection = db['courses']

# Bulk insert of courses with student enrollments
operations = [
    InsertOne({'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}),
    InsertOne({'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}),
    InsertOne({'course': 'History 201', 'enrollments': 20, 'department': 'History'}),
    InsertOne({'course': 'Physics 202', 'enrollments': 15, 'department': 'Physics'})
]
courses_collection.bulk_write(operations)
print('Courses inserted successfully.')
# Out:
# Courses inserted successfully.

# %%
# Task
from pymongo import MongoClient, InsertOne

# Establish client connection
client = MongoClient('mongodb+srv://akbarindra:Akbarmagelang0@cluster0.9rnw4.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
db = client['university_db']
courses = db['coursesnstudents']

# Dataset courses dengan student enrollments
courses_data = [
    {
        'course': 'Math 101',
        'enrollments': [
            {'student_id': 'S001', 'student_name': 'Reza'},
            {'student_id': 'S002', 'student_name': 'Rafi'},
            {'student_id': 'S003', 'student_name': 'Rahmad'}
        ],
        'department': 'Mathematics'
    },
    {
        'course': 'CS 102',
        'enrollments': [
            {'student_id': 'S004', 'student_name': 'David'},
            {'student_id': 'S005', 'student_name': 'Dian'}
        ],
        'department': 'Computer Science'
    },
    {
        'course': 'History 201',
        'enrollments': [
            {'student_id': 'S006', 'student_name': 'Guntur'},
            {'student_id': 'S007', 'student_name': 'Gandi'}
        ],
        'department': 'History'
    },
    {
        'course': 'Physics 202',
        'enrollments': [
            {'student_id': 'S008', 'student_name': 'Heri'},
            {'student_id': 'S009', 'student_name': 'Huda'}
        ],
        'department': 'Physics'
    }
]

# Bulk insert of courses with student enrollments
operations = [InsertOne(course) for course in courses_data]
courses.bulk_write(operations)
print('Courses with student enrollments inserted successfully.')

# Menampilkan data yang sudah disisipkan
for course in courses.find():
    print(course)
# Out:
# Courses with student enrollments inserted successfully.
# {'_id': ObjectId('6767af2e79e3099a91611736'), 'course': 'Math 101', 'enrollments': [{'student_id': 'S001', 'student_name': 'Reza'}, {'student_id': 'S002', 'student_name': 'Rafi'}, {'student_id': 'S003', 'student_name': 'Rahmad'}], 'department': 'Mathematics'}
# {'_id': ObjectId('6767af2e79e3099a91611737'), 'course': 'CS 102', 'enrollments': [{'student_id': 'S004', 'student_name': 'David'}, {'student_id': 'S005', 'student_name': 'Dian'}], 'department': 'Computer Science'}
# {'_id': ObjectId('6767af2e79e3099a91611738'), 'course': 'History 201', 'enrollments': [{'student_id': 'S006', 'student_name': 'Guntur'}, {'student_id': 'S007', 'student_name': 'Gandi'}], 'department': 'History'}
# {'_id': ObjectId('6767af2e79e3099a91611739'), 'course': 'Physics 202', 'enrollments': [{'student_id': 'S008', 'student_name': 'Heri'}, {'student_id': 'S009', 'student_name': 'Huda'}], 'department': 'Physics'}

# %% [markdown]
# ### 2. Complex Filtering and Querying
# - **Exercise 2**: Filter courses with enrollments over 20 students.
# - **Task 2**: Retrieve and display courses only from the 'Computer Science' or 'Mathematics' departments.

# %%
# Query for courses with enrollments greater than 20
for course in courses_collection.find({'enrollments': {'$gt': 20}}):
    print(course)
# Out:
# {'_id': ObjectId('6767af4879e3099a9161173b'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}
# {'_id': ObjectId('6767af4879e3099a9161173c'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}

# %%
# Query courses in Computer Science or Mathematics departments
for course in courses_collection.find({'department': {'$in': ['Computer Science', 'Mathematics']}}):
    print(course)
# Out:
# {'_id': ObjectId('6767af4879e3099a9161173b'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics'}
# {'_id': ObjectId('6767af4879e3099a9161173c'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science'}

# %% [markdown]
# ### 3. Aggregation Framework for Data Analysis
# - **Exercise 3**: Use aggregation to find the average enrollment per department.
# - **Task 3**: Create an aggregation pipeline that finds the maximum enrollment for each department.

# %%
# Average enrollment per department using aggregation
pipeline = [
    {'$group': {'_id': '$department', 'average_enrollment': {'$avg': '$enrollments'}}}
]
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': 'Physics', 'average_enrollment': 15.0}
# {'_id': 'Computer Science', 'average_enrollment': 25.0}
# {'_id': 'History', 'average_enrollment': 20.0}
# {'_id': 'Mathematics', 'average_enrollment': 30.0}

# %%
# Maximum enrollment per department
pipeline = [
    {'$group': {'_id': '$department', 'max_enrollment': {'$max': '$enrollments'}}}
]
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': 'Physics', 'max_enrollment': 15}
# {'_id': 'Computer Science', 'max_enrollment': 25}
# {'_id': 'History', 'max_enrollment': 20}
# {'_id': 'Mathematics', 'max_enrollment': 30}

# %% [markdown]
# ### 4. Data Transformation using $project and $addFields
# - **Exercise 4**: Use `$project` to rename and only show fields: `course_name`, `department_name`, and `enrollments`.
# - **Task 4**: Use `$addFields` to create a new field `enrollment_category` where enrollments > 20 are 'high' and others 'low'.

# %%
# Projection to rename fields
pipeline = [
    {'$project': {'course_name': '$course', 'department_name': '$department', 'enrollments': 1}}
]
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': ObjectId('6767af4879e3099a9161173b'), 'enrollments': 30, 'course_name': 'Math 101', 'department_name': 'Mathematics'}
# {'_id': ObjectId('6767af4879e3099a9161173c'), 'enrollments': 25, 'course_name': 'CS 102', 'department_name': 'Computer Science'}
# {'_id': ObjectId('6767af4879e3099a9161173d'), 'enrollments': 20, 'course_name': 'History 201', 'department_name': 'History'}
# {'_id': ObjectId('6767af4879e3099a9161173e'), 'enrollments': 15, 'course_name': 'Physics 202', 'department_name': 'Physics'}

# %%
# Adding enrollment category field based on enrollments
pipeline = [
    {'$addFields': {'enrollment_category': {'$cond': {'if': {'$gt': ['$enrollments', 20]}, 'then': 'high', 'else': 'low'}}}}
]
for result in courses_collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': ObjectId('6767af4879e3099a9161173b'), 'course': 'Math 101', 'enrollments': 30, 'department': 'Mathematics', 'enrollment_category': 'high'}
# {'_id': ObjectId('6767af4879e3099a9161173c'), 'course': 'CS 102', 'enrollments': 25, 'department': 'Computer Science', 'enrollment_category': 'high'}
# {'_id': ObjectId('6767af4879e3099a9161173d'), 'course': 'History 201', 'enrollments': 20, 'department': 'History', 'enrollment_category': 'low'}
# {'_id': ObjectId('6767af4879e3099a9161173e'), 'course': 'Physics 202', 'enrollments': 15, 'department': 'Physics', 'enrollment_category': 'low'}

# %% [markdown]
# ### Homework for Students
# - **Homework 1**: Perform an aggregation to get a count of courses per department.
# - **Homework 2**: Use `$match` and `$group` together to filter and get only courses with enrollments over 25 in 'Computer Science'.
# - **Homework 3**: Apply `$lookup` to join `courses` collection with `students` collection based on student enrollments.

# %%
# Homework 1
from pymongo import MongoClient

# Establish client connection
client = MongoClient('mongodb+srv://akbarindra:Akbarmagelang0@cluster0.9rnw4.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
db = client['university_db']
courses_collection = db['courses']

# Menggunakan agregasi untuk menghitung jumlah kursus per departemen
pipeline = [
    {"$group": {"_id": "$department","course_count": {"$sum": 1}}},
    {"$sort": {"course_count": -1}}
]

result = list(courses_collection.aggregate(pipeline))
for item in result:
    print(item)
# Out:
# {'_id': 'Physics', 'course_count': 1}
# {'_id': 'Mathematics', 'course_count': 1}
# {'_id': 'History', 'course_count': 1}
# {'_id': 'Computer Science', 'course_count': 1}

# %%
# Homework 2

pipeline = [
    {"$match": {
            "department": "Computer Science",
            "enrollments": {"$gt": 25}}},
    {"$group": {"_id": "$course","total_enrollments": {"$sum": "$enrollments"}}},
    {"$sort": {"total_enrollments": -1}}
]

result = list(courses_collection.aggregate(pipeline))
for item in result:
    print(item)

# %%
# Homework 3

from pymongo import MongoClient

client = MongoClient('mongodb+srv://akbarindra:Akbarmagelang0@cluster0.9rnw4.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
db = client['university_db']
courses_collection = db['courses']
coursesnstudents_collection = db['coursesnstudents']

# Aggregation Pipeline untuk melakukan join dengan $lookup
pipeline = [
    {"$lookup": {
            "from": "courses", 
            "localField": "course",
            "foreignField": "course", 
            "as": "course_details" }},
    { "$unwind": "$course_details" },
    {"$project": {
            "student_id": 1,
            "student_name": 1,
            "course": 1,
            "department": "$course_details.department", 
            "enrollments": "$course_details.enrollments" }}
]

# Jalankan pipeline agregasi
result = list(coursesnstudents_collection.aggregate(pipeline))

# Menampilkan hasil
for item in result:
    print(item)
# Out:
# {'_id': ObjectId('6767af2e79e3099a91611736'), 'course': 'Math 101', 'department': 'Mathematics', 'enrollments': 30}
# {'_id': ObjectId('6767af2e79e3099a91611737'), 'course': 'CS 102', 'department': 'Computer Science', 'enrollments': 25}
# {'_id': ObjectId('6767af2e79e3099a91611738'), 'course': 'History 201', 'department': 'History', 'enrollments': 20}
# {'_id': ObjectId('6767af2e79e3099a91611739'), 'course': 'Physics 202', 'department': 'Physics', 'enrollments': 15}
